# %%
# !mamba install -c bioconda -y pyopenms
# Out:
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██�� ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (1.3.1) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['pyopenms']
#
# bioconda/osx-64                                             Using cache
# bioconda/noarch                                             Using cache
# conda-forge/osx-64                                          Using cache
# conda-forge/noarch                                          Using cache
# [+] 0.0s
# [+] 0.1s
# pkgs/main/osx-64 ╸━━━━━━━━━━━━━━━╸━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# pkgs/main/noarch ━━━━━━━━━━━━━╸━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# pkgs/r/osx-64    ━━━━━━━━━━━━╸━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# pkgs/r/noarch    ╸━━━━━━━━━━━━━━━╸━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s[+] 0.2s
# pkgs/main/osx-64 ━╸━━━━━━━━━━━━━━━╸━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s
# pkgs/main/noarch ━━━━━━━━━━━━━━━╸━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s
# pkgs/r/osx-64    ━━━━━━━━━━━━━╸━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s
# pkgs/r/noarch    ━╸━━━━━━━━━━━━━━━╸━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2spkgs/main/osx-64                                              No change
# pkgs/r/noarch                                                 No change
# pkgs/r/osx-64                                                 No change
# pkgs/main/noarch                                              No change
#
# Pinned packages:
#   - python 3.10.*
#
#
# Transaction
#
#   Prefix: /Users/anthony.cesnik/Dropbox/Dropbox/Research/Project/Active/CellCyclePhospho/cellcyclephospho0/.conda
#
#   Updating specs:
#
#    - pyopenms
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package               Version  Build               Channel                  Size
# ────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ────────────────────────────────────────────────────────────────────────────────────
#
#   + boost-cpp            1.74.0  hdbf7018_7          conda-forge/osx-64       16MB
#   + c-ares               1.18.1  h0d85af4_0          conda-forge/osx-64     Cached
#   + coinmp                1.8.4  h4cbccac_3          conda-forge/osx-64        8MB
#   + eigen                 3.4.0  h940c156_0          conda-forge/osx-64        1MB
#   + hdf5                 1.14.0  nompi_hbf0aa07_102  conda-forge/osx-64     Cached
#   + icu                    69.1  he49afe7_0          conda-forge/osx-64       13MB
#   + jpeg                     9e  hac89ed1_2          conda-forge/osx-64      267kB
#   + krb5                 1.20.1  h049b76e_0          conda-forge/osx-64     Cached
#   + libaec                1.0.6  hf0c8a7f_1          conda-forge/osx-64     Cached
#   + libclang             13.0.1  default_he082bbe_0  conda-forge/osx-64        8MB
#   + libcurl              7.88.1  h6df9250_1          conda-forge/osx-64      344kB
#   + libedit        3.1.20191231  h0678c8f_2          conda-forge/osx-64     Cached
#   + libev                  4.33  haf1e3a3_1          conda-forge/osx-64     Cached
#   + libllvm13            13.0.1  h64f94b2_2          conda-forge/osx-64       27MB
#   + libnghttp2           1.52.0  he2ab024_0          conda-forge/osx-64      613kB
#   + libopenms             2.9.1  hd458969_1          bioconda/osx-64          17MB
#   + libpq                  14.5  h3640bf0_5          conda-forge/osx-64        2MB
#   + libssh2              1.10.0  h47af595_3          conda-forge/osx-64     Cached
#   + libsvm                 3.21  1                   conda-forge/osx-64       64kB
#   + mysql-common         8.0.32  hc4b2c72_1          conda-forge/osx-64      746kB
#   + mysql-libs           8.0.32  h8658499_1          conda-forge/osx-64        1MB
#   + nspr                   4.35  hea0b92c_0          conda-forge/osx-64      230kB
#   + nss                    3.89  h78b00b3_0          conda-forge/osx-64        2MB
#   + pyopenms              2.9.1  py310h405c6ce_0     bioconda/osx-64           9MB
#   + qt                   5.12.9  h2a607e2_5          conda-forge/osx-64       92MB
#   + xerces-c              3.2.3  h6564042_4          conda-forge/osx-64        2MB
#
#   Change:
# ────────────────────────────────────────────────────────────────────────────────────
#
#   - lcms2                  2.15  h2dcdeff_1          conda-forge
#   + lcms2                  2.15  h29502cd_0          conda-forge/osx-64      228kB
#   - libtiff               4.5.0  hd920806_5          conda-forge
#   + libtiff               4.5.0  hee9004a_2          conda-forge/osx-64     Cached
#   - pillow                9.4.0  py310h6b2f720_2     conda-forge
#   + pillow                9.4.0  py310h306a057_1     conda-forge/osx-64       46MB
#
#   Upgrade:
# ────────────────────────────────────────────────────────────────────────────────────
#
#   - openssl               3.0.8  hfd90126_0          conda-forge
#   + openssl               3.1.0  hfd90126_0          conda-forge/osx-64        2MB
#
#   Downgrade:
# ────────────────────────────────────────────────────────────────────────────────────
#
#   - libjpeg-turbo       2.1.5.1  hb7f2c08_0          conda-forge
#   + libjpeg-turbo         2.1.4  hb7f2c08_0          conda-forge/osx-64      944kB
#   - llvm-openmp          15.0.7  h61d9ccf_0          conda-forge
#   + llvm-openmp          14.0.6  h61d9ccf_0          conda-forge/osx-64      338kB
#   - numpy                1.24.2  py310h788a5b3_0     conda-forge
#   + numpy                1.23.5  py310h1b7c290_0     conda-forge/osx-64        6MB
#
#   Summary:
#
#   Install: 26 packages
#   Change: 3 packages
#   Upgrade: 1 packages
#   Downgrade: 3 packages
#
#   Total download: 256MB
#
# ────────────────────────────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B                            0.0s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 0.1s
# Downloading  (5) ╸━━━━━━━━━━━━━━━━━━━━━━   0.0 B coinmp                     0.0s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 0.2s
# Downloading  (5) ╸━━━━━━━━━━━━━━━━━━━━━━ 637.8kB coinmp                     0.1s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0seigen                                                1.3MB @   5.2MB/s  0.2s
# numpy                                                5.6MB @  20.9MB/s  0.3s
# [+] 0.3s
# Downloading  (5) ━━━╸━━━━━━━━━━━━━━━━━━━  12.3MB coinmp                     0.2s
# Extracting   (2) ━━━━━━━━━╸━━━━━━━━━━━━━       0 eigen                      0.0sopenssl                                              2.3MB @   7.6MB/s  0.3s
# libnghttp2                                         613.1kB @   1.7MB/s  0.0s
# libjpeg-turbo                                      944.4kB @   2.5MB/s  0.4s
# [+] 0.4s
# Downloading  (5) ╸━━━━━━━╸━━━━━━━━━━━━━━  18.6MB coinmp                     0.3s
# Extracting   (5) ━━━━━━━━━━╸━━━━━━━━━━━━       0 eigen                      0.1slcms2                                              227.7kB @ 518.1kB/s  0.1s
# [+] 0.5s
# Downloading  (5) ━╸━━━━━━━━╸━━━━━━━━━━━━  24.1MB libllvm13                  0.4s
# Extracting   (6) ━━━━━━━━━━━╸━━━━━━━━━━━       0 eigen                      0.2s[+] 0.6s
# Downloading  (5) ━╸━━━━━━━━╸━━━━━━━━━━━━  26.0MB libllvm13                  0.5s
# Extracting   (6) ━━━━━━━━━━━━━╸━━━━━━━━━       0 eigen                      0.3sxerces-c                                             1.5MB @   2.3MB/s  0.4s
# [+] 0.7s
# Downloading  (5) ━╸━━━━━━━━━━╸━━━━━━━━━━  34.4MB libllvm13                  0.6s
# Extracting   (7) ━━━━━━━━━━━━━━╸━━━━━━━━       0 lcms2                      0.4s[+] 0.8s
# Downloading  (5) ━━╸━━━━━━━━━━╸━━━━━━━━━  44.2MB libllvm13                  0.7s
# Extracting   (7) ━━━━━━━━━━━━━━━╸━━━━━━━       0 lcms2                      0.5s[+] 0.9s
# Downloading  (5) ━━━╸━━━━━━━━━╸━━━━━━━━━  49.0MB pillow                     0.8s
# Extracting   (7) ╸━━━━━━━━━━━━━━━╸━━━━━━       0 lcms2                      0.6s[+] 1.0s
# Downloading  (5) ━━━╸━━━━━━━━━╸━━━━━━━━━  55.4MB pillow                     0.9s
# Extracting   (7) ━╸━━━━━━━━━━━━━━━╸━━━━━       0 lcms2                      0.7s[+] 1.1s
# Downloading  (6) ━━━━╸━━━━━━━━━━━╸━━━━━━  65.4MB pillow                     1.0s
# Extracting   (7) ━━╸━━━━━━━━━━━━━━━╸━━━━       0 libjpeg-turbo              0.8scoinmp                                               7.8MB @   7.4MB/s  1.1s
# [+] 1.2s
# Downloading  (5) ━━━━━╸━━━━━━━━━━━╸━━━━━  73.5MB pillow                     1.1s
# Extracting   (8) ━━━╸━━━━━━━━━━━━━━━╸━━━       0 libjpeg-turbo              0.9s[+] 1.3s
# Downloading  (5) ━━━━━━╸━━━━━━━━━━━╸━━━━  83.3MB pyopenms                   1.2s
# Extracting   (8) ━━━━╸━━━━━━━━━━━━━━━╸━━       0 libjpeg-turbo              1.0slibllvm13                                           26.5MB @  19.7MB/s  1.1s
# pyopenms                                             8.8MB @   6.4MB/s  0.9s
# [+] 1.4s
# Downloading  (5) ━━━━━━╸━━━━━━━━━━━╸━━━━  88.9MB boost-cpp                  1.3s
# Extracting  (10) ━━━━━╸━━━━━━━━━━━━━━━╸━       0 libjpeg-turbo              1.1sicu                                                 13.5MB @   9.6MB/s  0.7s
# mysql-libs                                           1.5MB @   1.0MB/s  0.1s
# libcurl                                            344.2kB @ 238.4kB/s  0.1s
# [+] 1.5s
# Downloading  (4) ━━━━━━━╸━━━━━━━━━━━╸━━━  99.4MB boost-cpp                  1.4s
# Extracting  (14) ━━━━━━╸━━━━━━━━━━━━━━━━       0 libllvm13                  1.2smysql-common                                       745.7kB @ 499.7kB/s  0.1s
# jpeg                                               266.7kB @ 174.3kB/s  0.1s
# nss                                                  1.9MB @   1.2MB/s  0.1s
# [+] 1.6s
# Downloading  (6) ━━━━━━━━╸━━━━━━━━━━━━━━ 105.8MB boost-cpp                  1.5s
# Extracting  (16) ━━━━━━━━╸━━━━━━━━━━━━━━       0 libllvm13                  1.3sllvm-openmp                                        337.9kB @ 213.2kB/s  0.1s
# [+] 1.7s
# Downloading  (5) ━━━━━━━━━╸━━━━━━━━━━━━━ 116.1MB boost-cpp                  1.6s
# Extracting  (17) ━━━━━━━━━╸━━━━━━━━━━━━━       0 libllvm13                  1.4s[+] 1.8s
# Downloading  (5) ━━━━━━━━━━╸━━━━━━━━━━━━ 125.3MB libclang                   1.7s
# Extracting  (16) ━━━━━━━━━━╸━━━━━━━━━━━━       1 libllvm13                  1.5slibsvm                                              64.3kB @  35.8kB/s  0.3s
# libclang                                             8.4MB @   4.5MB/s  0.3s
# [+] 1.9s
# Downloading  (5) ━━━━━━━━━━╸━━━━━━━━━━━━ 135.8MB boost-cpp                  1.8s
# Extracting  (18) ━━━━━━━━━━━╸━━━━━━━━━━━       1 libnghttp2                 1.6s[+] 2.0s
# Downloading  (5) ━━━━━━━━━━╸━━━━━━━━━━━━ 135.8MB boost-cpp                  1.9s
# Extracting  (18) ━━━━━━━━━━━━╸━━━━━━━━━━       1 libnghttp2                 1.7s[+] 2.1s
# Downloading  (5) ━━━━━━━━━━━╸━━━━━━━━━━━ 145.7MB boost-cpp                  2.0s
# Extracting  (18) ━━━━━━━╸━━━━━━━━━━━━━━━       1 libnghttp2                 1.8sboost-cpp                                           16.4MB @   7.8MB/s  1.0s
# libpq                                                2.2MB @   1.0MB/s  0.3s
# nspr                                               230.1kB @ 105.7kB/s  0.1s
# pillow                                              46.2MB @  21.2MB/s  1.8s
# [+] 2.2s
# Downloading  (2) ━━━━━━━━━━━━╸━━━━━━━━━━ 153.1MB libopenms                  2.1s
# Extracting  (22) ━━━━━━━━╸━━━━━━━━━━━━━━       1 libnghttp2                 1.9s[+] 2.3s
# Downloading  (2) ━━━━━━━━━━━━━╸━━━━━━━━━ 158.0MB libopenms                  2.2s
# Extracting  (22) ━━━━━━━━━╸━━━━━━━━━━━━━       1 libpq                      2.0s[+] 2.4s
# Downloading  (2) ━━━━━━━━━━━━━╸━━━━━━━━━ 161.6MB libopenms                  2.3s
# Extracting  (22) ━━━━━━━━━━╸━━━━━━━━━━━━       1 libpq                      2.1s[+] 2.5s
# Downloading  (2) ━━━━━━━━━━━━━╸━━━━━━━━━ 166.4MB libopenms                  2.4s
# Extracting  (22) ━━━━━━━━━━━╸━━━━━━━━━━━       1 libpq                      2.2s[+] 2.6s
# Downloading  (2) ━━━━━━━━━━━━━━╸━━━━━━━━ 176.1MB qt                         2.5s
# Extracting  (22) ━━━━━━━━━━━━━╸━━━━━━━━━       1 libpq                      2.3s[+] 2.7s
# Downloading  (2) ━━━━━━━━━━━━━━╸━━━━━━━━ 176.1MB qt                         2.6s
# Extracting  (22) ━━━━━━━━━━━━━━╸━━━━━━━━       1 libsvm                     2.4s[+] 2.8s
# Downloading  (2) ━━━━━━━━━━━━━━━╸━━━━━━━ 182.6MB qt                         2.7s
# Extracting  (22) ━━━━━━━━━━━━━━━╸━━━━━━━       1 libsvm                     2.5slibopenms                                           16.6MB @   5.8MB/s  1.0s
# [+] 2.9s
# Downloading  (1) ━━━━━━━━━━━━━━━━╸━━━━━━ 193.9MB qt                         2.8s
# Extracting  (23) ╸━━━━━━━━━━━━━━━╸━━━━━━       1 libsvm                     2.6s[+] 3.0s
# Downloading  (1) ━━━━━━━━━━━━━━━━╸━━━━━━ 200.4MB qt                         2.9s
# Extracting  (23) ━╸━━━━━━━━━━━━━━━╸━━━━━       1 libsvm                     2.7s[+] 3.1s
# Downloading  (1) ━━━━━━━━━━━━━━━━━╸━━━━━ 211.4MB qt                         3.0s
# Extracting  (23) ━━╸━━━━━━━━━━━━━━━╸━━━━       1 llvm-openmp                2.8s[+] 3.2s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━╸━━━━ 214.4MB qt                         3.1s
# Extracting  (23) ━━━╸━━━━━━━━━━━━━━━╸━━━       1 llvm-openmp                2.9s[+] 3.3s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━╸━━━━ 220.0MB qt                         3.2s
# Extracting  (23) ━━━━╸━━━━━━━━━━━━━━━╸━━       1 llvm-openmp                3.0s[+] 3.4s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━╸━━━ 224.5MB qt                         3.3s
# Extracting  (23) ━━━━━╸━━━━━━━━━━━━━━━╸━       1 llvm-openmp                3.1s[+] 3.5s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━╸━━━ 234.5MB qt                         3.4s
# Extracting  (23) ━━━━━━╸━━━━━━━━━━━━━━━━       1 mysql-common               3.2s[+] 3.6s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━╸━━ 242.0MB qt                         3.5s
# Extracting  (23) ━━━━━━━━╸━━━━━━━━━━━━━━       1 mysql-common               3.3s[+] 3.7s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━╸━ 251.3MB qt                         3.6s
# Extracting  (23) ━━━━━━━━━╸━━━━━━━━━━━━━       1 mysql-common               3.4sqt                                                  92.2MB @  24.5MB/s  2.2s
# [+] 3.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (24) ━━━━━━━━━━╸━━━━━━━━━━━━       1 mysql-common               3.5s[+] 3.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (23) ╸━━━━━━━━━━━━━━━━━━━━━━       2 mysql-libs                 3.6s[+] 4.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (23) ╸━━━━━━━━━━━━━━━━━━━━━━       2 mysql-libs                 3.7s[+] 4.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (22) ━╸━━━━━━━━━━━━━━━━━━━━━       3 mysql-libs                 3.8s[+] 4.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (21) ━━╸━━━━━━━━━━━━━━━━━━━━       4 mysql-libs                 3.9s[+] 4.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (21) ━━╸━━━━━━━━━━━━━━━━━━━━       4 nspr                       4.0s[+] 4.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (20) ━━━╸━━━━━━━━━━━━━━━━━━━       5 nspr                       4.1s[+] 4.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (19) ━━━━╸━━━━━━━━━━━━━━━━━━       6 nspr                       4.2s[+] 4.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (19) ━━━━╸━━━━━━━━━━━━━━━━━━       6 nspr                       4.3s[+] 4.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (19) ━━━━╸━━━━━━━━━━━━━━━━━━       6 nss                        4.4s[+] 4.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (19) ━━━━╸━━━━━━━━━━━━━━━━━━       6 nss                        4.5s[+] 4.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (19) ━━━━╸━━━━━━━━━━━━━━━━━━       6 nss                        4.6s[+] 5.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (19) ━━━━╸━━━━━━━━━━━━━━━━━━       6 nss                        4.7s[+] 5.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (19) ━━━━╸━━━━━━━━━━━━━━━━━━       6 pillow                     4.8s[+] 5.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (19) ━━━━╸━━━━━━━━━━━━━━━━━━       6 pillow                     4.9s[+] 5.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (18) ━━━━━╸━━━━━━━━━━━━━━━━━       7 pillow                     5.0s[+] 5.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (18) ━━━━━╸━━━━━━━━━━━━━━━━━       7 pillow                     5.1s[+] 5.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (18) ━━━━━╸━━━━━━━━━━━━━━━━━       7 pyopenms                   5.2s[+] 5.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (18) ━━━━━╸━━━━━━━━━━━━━━━━━       7 pyopenms                   5.3s[+] 5.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (18) ━━━━━╸━━━━━━━━━━━━━━━━━       7 pyopenms                   5.4s[+] 5.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (18) ━━━━━╸━━━━━━━━━━━━━━━━━       7 pyopenms                   5.5s[+] 5.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (18) ━━━━━╸━━━━━━━━━━━━━━━━━       7 qt                         5.6s[+] 6.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (18) ━━━━━╸━━━━━━━━━━━━━━━━━       7 qt                         5.7s[+] 6.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (18) ━━━━━╸━━━━━━━━━━━━━━━━━       7 qt                         5.8s[+] 6.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (18) ━━━━━╸━━━━━━━━━━━━━━━━━       7 qt                         5.9s[+] 6.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (18) ━━━━━╸━━━━━━━━━━━━━━━━━       7 boost-cpp                  6.0s[+] 6.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (18) ━━━━━╸━━━━━━━━━━━━━━━━━       7 boost-cpp                  6.1s[+] 6.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (18) ━━━━━╸━━━━━━━━━━━━━━━━━       7 boost-cpp                  6.2s[+] 6.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (18) ━━━━━╸━━━━━━━━━━━━━━━━━       7 boost-cpp                  6.3s[+] 6.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (18) ━━━━━╸━━━━━━━━━━━━━━━━━       7 coinmp                     6.4s[+] 6.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (18) ━━━━━╸━━━━━━━━━━━━━━━━━       7 coinmp                     6.5s[+] 6.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (18) ━━━━━╸━━━━━━━━━━━━━━━━━       7 coinmp                     6.6s[+] 7.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (18) ━━━━━╸━━━━━━━━━━━━━━━━━       7 coinmp                     6.7s[+] 7.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (17) ━━━━━━╸━━━━━━━━━━━━━━━━       8 boost-cpp                  6.8s[+] 7.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (17) ━━━━━━╸━━━━━━━━━━━━━━━━       8 boost-cpp                  6.9s[+] 7.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (17) ━━━━━━╸━━━━━━━━━━━━━━━━       8 boost-cpp                  7.0s[+] 7.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (17) ━━━━━━╸━━━━━━━━━━━━━━━━       8 boost-cpp                  7.1s[+] 7.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (17) ━━━━━━╸━━━━━━━━━━━━━━━━       8 icu                        7.2s[+] 7.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (17) ━━━━━━╸━━━━━━━━━━━━━━━━       8 icu                        7.3s[+] 7.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (17) ━━━━━━╸━━━━━━━━━━━━━━━━       8 icu                        7.4s[+] 7.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (17) ━━━━━━╸━━━━━━━━━━━━━━━━       8 icu                        7.5s[+] 7.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (17) ━━━━━━╸━━━━━━━━━━━━━━━━       8 jpeg                       7.6s[+] 8.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (17) ━━━━━━╸━━━━━━━━━━━━━━━━       8 jpeg                       7.7s[+] 8.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (17) ━━━━━━╸━━━━━━━━━━━━━━━━       8 jpeg                       7.8s[+] 8.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (17) ━━━━━━╸━━━━━━━━━━━━━━━━       8 jpeg                       7.9s[+] 8.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (17) ━━━━━━╸━━━━━━━━━━━━━━━━       8 libclang                   8.0s[+] 8.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (17) ━━━━━━╸━━━━━━━━━━━━━━━━       8 libclang                   8.1s[+] 8.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting  (17) ━━━━━━╸━━━━━━━━━━━━━━━━       8 
3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━━━╸━━      23 pillow                    58.0s[+] 58.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━━━╸━━      23 pillow                    58.1s[+] 58.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━━━╸━━      23 pillow                    58.2s[+] 58.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━━━╸━━      23 qt                        58.3s[+] 58.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━━━╸━━      23 qt                        58.4s[+] 58.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━━━╸━━      23 qt                        58.5s[+] 58.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━━━╸━━      23 qt                        58.6s[+] 59.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━━━╸━━      23 pillow                    58.7s[+] 59.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━━━╸━━      23 pillow                    58.8s[+] 59.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━━━╸━━      23 pillow                    58.9s[+] 59.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━━━╸━━      23 pillow                    59.0s[+] 59.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━━━╸━━      23 qt                        59.1s[+] 59.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━━━╸━━      23 qt                        59.2s[+] 59.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━━━╸━━      23 qt                        59.3s[+] 59.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━━━╸━━      23 qt                        59.4s[+] 59.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━━━╸━━      23 pillow                    59.5s[+] 59.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━━━╸━━      23 pillow                    59.6s[+] 1m:0.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━━━╸━━      23 pillow                    59.7s[+] 1m:0.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━━━╸━━      23 pillow                    59.8s[+] 1m:0.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━━━╸━━      23 qt                        59.9s[+] 1m:0.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 256.3MB                            3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━━━╸━━      23 qt                        60.0s[+] 1m:0.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 qt                        1m:0.1s[+] 1m:0.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 qt                        1m:0.2s[+] 1m:0.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 pillow                    1m:0.3s[+] 1m:0.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 pillow                    1m:0.4s[+] 1m:0.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 pillow                    1m:0.5s[+] 1m:0.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 pillow                    1m:0.6s[+] 1m:1.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 qt                        1m:0.7s[+] 1m:1.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 qt                        1m:0.8s[+] 1m:1.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 qt                        1m:0.9s[+] 1m:1.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 qt                        1m:1.0s[+] 1m:1.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 pillow                    1m:1.1s[+] 1m:1.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 pillow                    1m:1.2s[+] 1m:1.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 pillow                    1m:1.3s[+] 1m:1.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 pillow                    1m:1.4s[+] 1m:1.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 qt                        1m:1.5s[+] 1m:1.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 qt                        1m:1.6s[+] 1m:2.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 qt                        1m:1.7s[+] 1m:2.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 qt                        1m:1.8s[+] 1m:2.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 pillow                    1m:1.9s[+] 1m:2.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 pillow                    1m:2.0s[+] 1m:2.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 pillow                    1m:2.1s[+] 1m:2.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 pillow                    1m:2.2s[+] 1m:2.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 qt                        1m:2.3s[+] 1m:2.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 qt                        1m:2.4s[+] 1m:2.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 qt                        1m:2.5s[+] 1m:2.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 qt                        1m:2.6s[+] 1m:3.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 pillow                    1m:2.7s[+] 1m:3.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 pillow                    1m:2.8s[+] 1m:3.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 pillow                    1m:2.9s[+] 1m:3.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 pillow                    1m:3.0s[+] 1m:3.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 qt                        1m:3.1s[+] 1m:3.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 qt                        1m:3.2s[+] 1m:3.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 qt                        1m:3.3s[+] 1m:3.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 qt                        1m:3.4s[+] 1m:3.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 pillow                    1m:3.5s[+] 1m:3.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 pillow                    1m:3.6s[+] 1m:4.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 pillow                    1m:3.7s[+] 1m:4.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 pillow                    1m:3.8s[+] 1m:4.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━╸━━      23 qt                        1m:3.9s[+] 1m:4.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (1) ━━━━━━━━━━━━━━━━━━━╸━      24 pillow                    1m:4.0s[+] 1m:4.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (1) ━━━━━━━━━━━━━━━━━━━╸━      24 pillow                    1m:4.1s[+] 1m:4.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (1) ━━━━━━━━━━━━━━━━━━━╸━      24 pillow                    1m:4.2s[+] 1m:4.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (1) ━━━━━━━━━━━━━━━━━━━╸━      24 pillow                    1m:4.3s[+] 1m:4.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (1) ━━━━━━━━━━━━━━━━━━━╸━      24 pillow                    1m:4.4s[+] 1m:4.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (1) ━━━━━━━━━━━━━━━━━━━╸━      24 pillow                    1m:4.5s[+] 1m:4.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (1) ━━━━━━━━━━━━━━━━━━━╸━      24 pillow                    1m:4.6s[+] 1m:5.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (1) ━━━━━━━━━━━━━━━━━━━╸━      24 pillow                    1m:4.7s[+] 1m:5.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (1) ━━━━━━━━━━━━━━━━━━━╸━      24 pillow                    1m:4.8s[+] 1m:5.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (1) ━━━━━━━━━━━━━━━━━━━╸━      24 pillow                    1m:4.9s[+] 1m:5.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (1) ━━━━━━━━━━━━━━━━━━━╸━      24 pillow                    1m:5.0s[+] 1m:5.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (1) ━━━━━━━━━━━━━━━━━━━╸━      24 pillow                    1m:5.1s[+] 1m:5.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (1) ━━━━━━━━━━━━━━━━━━━╸━      24 pillow                    1m:5.2s[+] 1m:5.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━ 256.3MB                              3.7s
# Extracting   (1) ━━━━━━━━━━━━━━━━━━━╸━      24 pillow                    1m:5.3s
# Downloading and Extracting Packages
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
import pyopenms
import matplotlib.pyplot as plt

# Load mzML file
filename = "data/SmallCalibratible_Yeast.mzML"
exp = pyopenms.MSExperiment()
pyopenms.MzMLFile().load(filename, exp)

# Extract the first spectrum
spectrum = exp[0]

# Extract the m/z and intensity arrays from the spectrum
mz_array = spectrum.get_peaks()[0]
intensity_array = spectrum.get_peaks()[1]

# Plot the spectrum using matplotlib
plt.plot(mz_array, intensity_array)
plt.xlabel('m/z')
plt.ylabel('Intensity')
plt.title('Mass Spectrum')
plt.show()
# Out:
# Warning: OPENMS_DATA_PATH environment variable not found and no share directory was installed. Some functionality might not work as expected.
# Determination of memory status is not supported on this
#  platform, measuring for memoryleaks will never fail
